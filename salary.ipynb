# %%
import pandas as pd

# %%
dataset=pd.read_csv("Salary_dataset.csv")

# %%
x=dataset.iloc[:,1]
x.head()
# Out:
# 0    1.2
# 1    1.4
# 2    1.6
# 3    2.1
# 4    2.3
# Name: YearsExperience, dtype: float64

# %%
y=dataset.iloc[:,2]
y.head()
# Out:
# 0    39344.0
# 1    46206.0
# 2    37732.0
# 3    43526.0
# 4    39892.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
print(x_train.shape)  # Should be (n_samples, n_features)
print(y_train.shape)  # Should be (n_samples,)
# Out:
# (24,)
# (24,)

# %%
# Ensure x_train is a DataFrame
if isinstance(x_train, pd.Series):
    x_train = x_train.to_frame()

# Ensure y_train is a Series
if isinstance(y_train, pd.DataFrame):
    y_train = y_train.squeeze()  # Convert DataFrame with one column to Series

# %%
x_train = pd.DataFrame(x_train).apply(pd.to_numeric, errors='coerce')
y_train = pd.Series(y_train).apply(pd.to_numeric, errors='coerce')

# %%
from sklearn.linear_model import LinearRegression

# Sample data preparation
x_train = pd.DataFrame({'YearsExperience': [1.2, 1.4, 1.6, 2.1]})  # Example feature
y_train = pd.Series([39344.0, 46206.0, 37732.0, 43526.0])  # Example target

# Initialize and fit the model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[2.1]])
# Out:
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([42821.68715084])
